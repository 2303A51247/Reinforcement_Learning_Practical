# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51247/Reinforcement_Learning_Practical/blob/main/RL_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def random_agent(env_name, episodes=5):
    env = gym.make(env_name)

    for episode in range(1, episodes + 1):
        state, info = env.reset()
        total_reward = 0
        steps = 0
        terminated = False
        truncated = False

        while not (terminated or truncated):
            action = env.action_space.sample()

            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            steps += 1
            state = next_state

        average_reward = total_reward / steps if steps > 0 else 0

        print(f"Environment: {env_name}")
        print(f"Episode: {episode}")
        print(f"Total Reward: {total_reward}")
        print(f"Average Reward: {average_reward:.2f}")
        print(f"Steps: {steps}")
        print("-" * 30)

    env.close()


random_agent("CliffWalking-v1", episodes=5)
random_agent("Taxi-v4", episodes=5)
# Out:
# Environment: CliffWalking-v1
# Episode: 1
# Total Reward: -16932
# Average Reward: -12.19
# Steps: 1389
# ------------------------------
# Environment: CliffWalking-v1
# Episode: 2
# Total Reward: -35487
# Average Reward: -9.83
# Steps: 3609
# ------------------------------
# Environment: CliffWalking-v1
# Episode: 3
# Total Reward: -51584
# Average Reward: -9.64
# Steps: 5351
# ------------------------------
# Environment: CliffWalking-v1
# Episode: 4
# Total Reward: -9594
# Average Reward: -10.88
# Steps: 882
# ------------------------------
# Environment: CliffWalking-v1
# Episode: 5
# Total Reward: -12375
# Average Reward: -10.42
# Steps: 1188
# ------------------------------
# Environment: Taxi-v4
# Episode: 1
# Total Reward: -758
# Average Reward: -3.79
# Steps: 200
# ------------------------------
# Environment: Taxi-v4
# Episode: 2
# Total Reward: -803
# Average Reward: -4.01
# Steps: 200
# ------------------------------
# Environment: Taxi-v4
# Episode: 3
# ...
